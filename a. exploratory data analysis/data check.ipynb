# %%
import pandas as pd

df = pd.read_csv('C:/Users/loydt/Documents/datasets/Electronic_sales_Sep2023-Sep2024.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   customer id        1 non-null      int64
#  1   age                1 non-null      int64
#  2   gender             1 non-null      object
#  3   loyalty member     1 non-null      object
#  4   product type       1 non-null      object
#  5   sku                1 non-null      object
#  6   rating             1 non-null      int64
#  7   order status       1 non-null      object
#  8   payment method     1 non-null      object
#  9   total price        1 non-null      float64
#  10  unit price         1 non-null      float64
#  11  quantity           1 non-null      int64
#  12  purchase date      1 non-null      object
#  13  shipping type      1 non-null      object
#  14  add-ons purchased  0 non-null      object
#  15  add-on total       1 non-null      float64
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Loyalty Member', 'Product Type', 'SKU',
#        'Rating', 'Order Status', 'Payment Method', 'Total Price', 'Unit Price',
#        'Quantity', 'Purchase Date', 'Shipping Type', 'Add-ons Purchased',
#        'Add-on Total'],
#       dtype='object')

# %%
df = df[df.isna().any(axis=1)]
df
# Out:
#        Customer ID  Age  Gender Loyalty Member Product Type      SKU  Rating  \
# 2             1002   41    Male             No       Laptop  SKU1005       3
# 6             1005   25  Female             No   Smartwatch  SKU1003       3
# 9             1006   24    Male            Yes       Laptop  SKU1005       3
# 18            1016   61    Male            Yes   Smartphone  SKU1001       5
# 20            1019   45    Male             No   Smartphone  SKU1001       5
# ...            ...  ...     ...            ...          ...      ...     ...
# 19991        19995   69  Female            Yes       Laptop   LTP123       3
# 19994        19996   27  Female             No   Smartphone   SMP234       5
# 19995        19996   27  Female             No   Smartphone   SMP234       4
# 19996        19996   27  Female            Yes       Laptop   LTP123       4
# 19999        19998   27     NaN            Yes       Laptop   LTP123       4
#
# ...
